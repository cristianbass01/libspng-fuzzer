# %%
import re
from collections import defaultdict
import json

def extract_error_paths(file_path, sanitizer_type):
    # Define patterns to extract information
    filename_pattern = re.compile(r".*?File name: (\S+)\n")
    if sanitizer_type == 'ASan':
        error_pattern = re.compile(r".*? AddressSanitizer: (\S+) on address")
    elif sanitizer_type == 'MSan':
        error_pattern = re.compile(r".*? MemorySanitizer: (\S+)\n")
    path_pattern = re.compile(r"    #\d+ 0x[0-9a-f]+ in (\S+)")

    errors = []

    with open(file_path, 'r') as f:
        content = f.read()

    # Split content by errors
    error_sections = content.split("----------------------------------------------------")

    for section in error_sections:

        section = section.split("\n\n")
        if len(section) < 2:
            section = "\n\n".join(section)
            last_three_points = section.rfind("...")
            print(section[last_three_points+3:])
            continue

        error_section = section[0]

        second_section = section[1]

        # Extract filename
        filename_match = filename_pattern.search(error_section)
        if not filename_match:
            continue
        filename = filename_match.group(1)

        # Extract error type
        error_match = error_pattern.search(error_section)
        if not error_match:
            continue
        
        error_type = error_match.group(1)
        
        # Extract paths
        path_matches = path_pattern.findall(error_section)
        paths = [match for match in path_matches if not match.startswith('_')]
        
        if sanitizer_type == 'ASan':
            # Extract allocation path
            allocation_matches = path_pattern.findall(second_section)
            allocations = [match for match in allocation_matches if not match.startswith('_')]
            errors.append({
                "file": filename,
                "error": error_type,
                "path": paths,
                "allocated_by": allocations
            })
        elif sanitizer_type == 'MSan':
            errors.append({
                "file": filename,
                "error": error_type,
                "path": paths
            })
    
    return errors

def find_unique_errors(results):
    unique_errors = []
    seen_errors = set()

    for result in results:

        error_tuple = (result['error'], tuple(result['path']))
        if 'allocated_by' in result:
            error_tuple += (tuple(result['allocated_by']),)
        if error_tuple not in seen_errors:
            seen_errors.add(error_tuple)
            result['files'] = set([result['file']])
            result.pop('file')
            unique_errors.append(result)
        else:
            for error in unique_errors:
                if error['error'] == result['error'] and error['path'] == result['path']:
                    error['files'].add(result['file'])
    
    for error in unique_errors:
        error['files'] = list(error['files'])
        error['files'].sort()
    
    return unique_errors

# %% [markdown]
# ## Analyze Asan errors

# %%
# Input file path
file_path = "./_crash_report_asan.txt"
results = extract_error_paths(file_path, 'ASan')

# Find unique errors
unique_results = find_unique_errors(results)
# Out:
#  =================================================================
# ==1094107==ERROR: AddressSanitizer: heap-buffer-overflow on address 0x503000000057 at pc 0x61e74649668f bp 0x7ffc29c32a10 sp 0x7ffc29c321c8
# READ of size 59 at 0x503000000057 thread T0
#
#  =================================================================
# ==1691427==ERROR: AddressSanitizer: heap-buffer-overflow on address 0x502000000053 at pc 0x574734493eec bp 0x7fff8cd8adc0 sp 0x7fff8cd8a568
# READ of size 4 at 0x502000000053 thread T0
#
#  =================================================================
# ==2280281==ERROR: AddressSanitizer: heap-buffer-overflow on address 0x502000000053 at pc 0x644e0b979eec bp 0x7ffd5512b5e0 sp 0x7ffd5512ad88
# READ of size 4 at 0x502000000053 thread T0
#
#  =================================================================
# ==2365957==ERROR: AddressSanitizer: heap-buffer-overflow on address 0x502000000038 at pc 0x60647463f68f bp 0x7ffca9b9a4f0 sp 0x7ffca9b99ca8
# READ of size 37 at 0x502000000038 thread T0
#
#  =================================================================
# ==3806229==ERROR: AddressSanitizer: heap-buffer-overflow on address 0x502000000053 at pc 0x5e226570eeec bp 0x7ffd6e57c9a0 sp 0x7ffd6e57c148
# READ of size 4 at 0x502000000053 thread T0
#
#  =================================================================
# ==3916543==ERROR: AddressSanitizer: heap-buffer-overflow on address 0x50200000007d at pc 0x5654341b968f bp 0x7ffc74464150 sp 0x7ffc74463908
# READ of size 22 at 0x50200000007d thread T0
#
#  =================================================================
# ==4043930==ERROR: AddressSanitizer: heap-buffer-overflow on address 0x50200000001b at pc 0x597773fa668f bp 0x7ffcc44980f0 sp 0x7ffcc44978a8
# READ of size 58 at 0x50200000001b thread T0
#
#  =================================================================
# ==106389==ERROR: AddressSanitizer: heap-buffer-overflow on address 0x502000000053 at pc 0x611c86476eec bp 0x7ffea0af2b00 sp 0x7ffea0af22a8
# READ of size 4 at 0x502000000053 thread T0
#
#  =================================================================
# ==346274==ERROR: AddressSanitizer: heap-buffer-overflow on address 0x504000000134 at pc 0x5e34c6d6568f bp 0x7ffe9671d1b0 sp 0x7ffe9671c968
# READ of size 97 at 0x504000000134 thread T0
#
#  =================================================================
# ==350296==ERROR: AddressSanitizer: heap-buffer-overflow on address 0x503000000082 at pc 0x5d9b49f8368f bp 0x7ffe994e8190 sp 0x7ffe994e7948
# READ of size 29 at 0x503000000082 thread T0
#
#  =================================================================
# ==1216842==ERROR: AddressSanitizer: heap-buffer-overflow on address 0x504000000134 at pc 0x5ec41be7868f bp 0x7fffcbf6a610 sp 0x7fffcbf69dc8
# READ of size 97 at 0x504000000134 thread T0
#
#  =================================================================
# ==1220897==ERROR: AddressSanitizer: heap-buffer-overflow on address 0x50300000008f at pc 0x61074262668f bp 0x7fff45a4ab50 sp 0x7fff45a4a308
# READ of size 99 at 0x50300000008f thread T0
#
#  =================================================================
# ==1221383==ERROR: AddressSanitizer: heap-buffer-overflow on address 0x50200000001b at pc 0x5d749eb3768f bp 0x7ffde7240c70 sp 0x7ffde7240428
# READ of size 58 at 0x50200000001b thread T0
#
#  =================================================================
# ==1222784==ERROR: AddressSanitizer: heap-buffer-overflow on address 0x504000000134 at pc 0x61c8c16a568f bp 0x7fff3552eed0 sp 0x7fff3552e688
# READ of size 97 at 0x504000000134 thread T0
#
#  =================================================================
# ==1228155==ERROR: AddressSanitizer: heap-buffer-overflow on address 0x504000000134 at pc 0x5906f297c68f bp 0x7ffeee9ac810 sp 0x7ffeee9abfc8
# READ of size 97 at 0x504000000134 thread T0
#
#  =================================================================
# ==1236257==ERROR: AddressSanitizer: heap-buffer-overflow on address 0x50200000001e at pc 0x5f8029f7068f bp 0x7ffe1be4ab50 sp 0x7ffe1be4a308
# READ of size 37 at 0x50200000001e thread T0

# %%
# Print the JSON content
print('Total errors: ', len(results))
print('Total unique errors: ', len(unique_results))
print(json.dumps(unique_results, indent=4))
# Out:
# Total errors:  11017
# Total unique errors:  5
# [
#     {
#         "error": "heap-buffer-overflow",
#         "path": [
#             "memcpy",
#             "memcpy",
#             "read_buf",
#             "fill_window",
#             "deflate_slow",
#             "deflate",
#             "compress2",
#             "write_chunks_before_idat",
#             "spng_encode_chunks",
#             "spng_encode_image",
#             "fuzz_spng_write",
#             "main"
#         ],
#         "allocated_by": [
#             "malloc",
#             "get_random_string",
#             "fuzz_spng_write",
#             "main"
#         ],
#         "files": [
#             "basi0g01",
#             "basi3p08",
#             "basn0g02",
#             "basn3p08",
#             "ccwn3p08",
#             "ch2n3p08",
#             "ctgn0g04",
#             "cthn0g04",
#             "ctjn0g04",
#             "ctzn0g04",
#             "g04n0g16",
#             "g05n3p04",
#             "g25n0g16",
#             "g25n3p04",
#             "tbbn3p08",
#             "tbgn2c16",
#             "tbgn3p08",
#             "tbwn3p08",
#             "tbyn3p08",
#             "tp0n3p08",
#             "tp1n3p08",
#             "xcsn0g01",
#             "xs2n0g01",
#             "xs7n0g01"
#         ]
#     },
#     {
#         "error": "heap-buffer-overflow",
#         "path": [
#             "memcpy",
#             "write_chunk",
#             "write_unknown_chunks",
#             "write_chunks_before_idat",
#             "spng_encode_chunks",
#             "spng_encode_image",
#             "fuzz_spng_write",
#             "main"
#         ],
#         "allocated_by": [
#             "malloc",
#             "get_random_string",
#             "fuzz_spng_write",
#             "main"
#         ],
#         "files": [
#             "basi0g01",
#             "basi0g02",
#             "basi0g04",
#             "basi0g16",
#             "basi2c16",
#             "basi3p04",
#             "basi3p08",
#             "basn0g01",
#             "basn0g02",
#             "basn0g04",
#             "basn2c16",
#             "basn3p04",
#             "basn3p08",
#             "ccwn3p08",
#             "ch1n3p04",
#             "ch2n3p08",
#             "cm0n0g04",
#             "cm7n0g04",
#             "cm9n0g04",
#             "cs3n2c16",
#             "cs3n3p08",
#             "cs5n3p08",
#             "cs8n3p08",
#             "ct0n0g04",
#             "ct1n0g04",
#             "cten0g04",
#             "ctfn0g04",
#             "ctgn0g04",
#             "cthn0g04",
#             "ctjn0g04",
#             "ctzn0g04",
#             "f99n0g04",
#             "g03n0g16",
#             "g03n3p04",
#             "g04n0g16",
#             "g04n3p04",
#             "g05n0g16",
#             "g05n3p04",
#             "g07n3p04",
#             "g10n0g16",
#             "g10n3p04",
#             "g25n0g16",
#             "g25n3p04",
#             "oi1n0g16",
#             "oi1n2c16",
#             "oi2n0g16",
#             "oi2n2c16",
#             "oi4n0g16",
#             "oi4n2c16",
#             "oi9n0g16",
#             "oi9n2c16",
#             "ps1n2c16",
#             "ps2n2c16",
#             "s05i3p02",
#             "s05n3p02",
#             "s06i3p02",
#             "s06n3p02",
#             "s07i3p02",
#             "s07n3p02",
#             "s08i3p02",
#             "s08n3p02",
#             "s09i3p02",
#             "s09n3p02",
#             "s32i3p04",
#             "s32n3p04",
#             "s33i3p04",
#             "s33n3p04",
#             "s34i3p04",
#             "s34n3p04",
#             "s35i3p04",
#             "s35n3p04",
#             "s36i3p04",
#             "s36n3p04",
#             "s37i3p04",
#             "s37n3p04",
#             "s38i3p04",
#             "s38n3p04",
#             "s39i3p04",
#             "s39n3p04",
#             "s40i3p04",
#             "s40n3p04",
#             "tbbn0g04",
#             "tbbn2c16",
#             "tbbn3p08",
#             "tbgn2c16",
#             "tbgn3p08",
#             "tbwn0g16",
#             "tbwn3p08",
#             "tbyn3p08",
#             "tp0n3p08",
#             "tp1n3p08",
#             "xcrn0g04",
#             "xcsn0g01",
#             "xdtn0g01",
#             "xlfn0g04",
#             "xs1n0g01",
#             "xs2n0g01",
#             "xs4n0g01",
#             "xs7n0g01"
#         ]
#     },
#     {
#         "error": "heap-buffer-overflow",
#         "path": [
#             "memcpy",
#             "write_chunk",
#             "write_unknown_chunks",
#             "write_chunks_after_idat",
#             "spng_encode_chunks",
#             "encode_scanline",
#             "encode_row",
#             "spng_encode_image",
#             "fuzz_spng_write",
#             "main"
#         ],
#         "allocated_by": [
#             "malloc",
#             "get_random_string",
#             "fuzz_spng_write",
#             "main"
#         ],
#         "files": [
#             "basi0g01",
#             "basi0g16",
#             "basi3p08",
#             "basn0g01",
#             "basn2c16",
#             "ccwn3p08",
#             "ch2n3p08",
#             "cm0n0g04",
#             "cm7n0g04",
#             "cm9n0g04",
#             "cs3n2c16",
#             "cs8n3p08",
#             "ct0n0g04",
#             "ct1n0g04",
#             "ctfn0g04",
#             "cthn0g04",
#             "ctzn0g04",
#             "f99n0g04",
#             "g03n0g16",
#             "g05n0g16",
#             "g07n0g16",
#             "g25n0g16",
#             "oi2n0g16",
#             "tbbn0g04",
#             "tbbn3p08",
#             "tbgn2c16",
#             "tbgn3p08",
#             "tbwn0g16",
#             "tbwn3p08",
#             "tbyn3p08",
#             "tp0n3p08",
#             "tp1n3p08",
#             "xcsn0g01",
#             "xdtn0g01",
#             "xs1n0g01",
#             "xs2n0g01",
#             "xs4n0g01",
#             "xs7n0g01"
#         ]
#     },
#     {
#         "error": "heap-buffer-overflow",
#         "path": [
#             "memcpy",
#             "write_chunk",
#             "write_unknown_chunks",
#             "write_chunks_after_idat",
#             "spng_encode_chunks",
#             "encode_scanline",
#             "encode_row",
#             "spng_encode_row",
#             "fuzz_spng_write",
#             "main"
#         ],
#         "allocated_by": [
#             "malloc",
#             "get_random_string",
#             "fuzz_spng_write",
#             "main"
#         ],
#         "files": [
#             "basi0g01",
#             "basi0g02",
#             "basi0g04",
#             "basi0g16",
#             "basi2c16",
#             "basi3p08",
#             "basn0g02",
#             "ccwn3p08",
#             "ch2n3p08",
#             "cm0n0g04",
#             "cm7n0g04",
#             "cm9n0g04",
#             "cs5n3p08",
#             "ct1n0g04",
#             "ctgn0g04",
#             "cthn0g04",
#             "ctjn0g04",
#             "ctzn0g04",
#             "g25n0g16",
#             "oi2n0g16",
#             "oi9n0g16",
#             "tbgn2c16",
#             "tbgn3p08",
#             "tp0n3p08",
#             "tp1n3p08",
#             "xcsn0g01",
#             "xs1n0g01",
#             "xs4n0g01",
#             "xs7n0g01"
#         ]
#     },
#     {
#         "error": "heap-buffer-overflow",
#         "path": [
#             "MemcmpInterceptorCommon(void*,",
#             "memcmp",
#             "check_exif",
#             "spng_set_exif",
#             "fuzz_spng_write",
#             "main"
#         ],
#         "allocated_by": [
#             "malloc",
#             "get_random_string",
#             "fuzz_spng_write",
#             "main"
#         ],
#         "files": [
#             "basi0g02",
#             "basi0g04",
#             "basi0g08",
#             "basi0g16",
#             "basi2c08",
#             "basi2c16",
#             "basi3p01",
#             "basi3p02",
#             "basi3p08",
#             "basi4a16",
#             "basi6a16",
#             "basn0g04",
#             "basn0g16",
#             "basn2c16",
#             "basn3p04",
#             "basn3p08",
#             "basn4a16",
#             "basn6a08",
#             "basn6a16",
#             "bgai4a08",
#             "bgai4a16",
#             "bgan6a08",
#             "bgan6a16",
#             "bgbn4a08",
#             "bggn4a16",
#             "bgwn6a08",
#             "bgyn6a16",
#             "ccwn2c08",
#             "ccwn3p08",
#             "cdfn2c08",
#             "cdhn2c08",
#             "cdsn2c08",
#             "ch1n3p04",
#             "ch2n3p08",
#             "cs3n2c16",
#             "cs3n3p08",
#             "cs5n2c08",
#             "cs5n3p08",
#             "ct0n0g04",
#             "ct1n0g04",
#             "cten0g04",
#             "ctfn0g04",
#             "ctgn0g04",
#             "ctjn0g04",
#             "ctzn0g04",
#             "exif2c08",
#             "f00n0g08",
#             "f00n2c08",
#             "f99n0g04",
#             "g03n0g16",
#             "g03n2c08",
#             "g03n3p04",
#             "g04n0g16",
#             "g04n2c08",
#             "g04n3p04",
#             "g05n0g16",
#             "g05n2c08",
#             "g05n3p04",
#             "g07n0g16",
#             "g07n2c08",
#             "g07n3p04",
#             "g10n0g16",
#             "g10n2c08",
#             "g10n3p04",
#             "g25n0g16",
#             "g25n2c08",
#             "g25n3p04",
#             "oi1n0g16",
#             "oi1n2c16",
#             "oi2n0g16",
#             "oi2n2c16",
#             "oi4n0g16",
#             "oi4n2c16",
#             "oi9n0g16",
#             "oi9n2c16",
#             "pp0n2c16",
#             "ps1n2c16",
#             "s04i3p01",
#             "s04n3p01",
#             "s07i3p02",
#             "s07n3p02",
#             "s09i3p02",
#             "s09n3p02",
#             "s33i3p04",
#             "s34i3p04",
#             "s37i3p04",
#             "s38i3p04",
#             "s38n3p04",
#             "s39n3p04",
#             "s40i3p04",
#             "s40n3p04",
#             "tbbn0g04",
#             "tbbn2c16",
#             "tbbn3p08",
#             "tbgn2c16",
#             "tbgn3p08",
#             "tbrn2c08",
#             "tbwn0g16",
#             "tbwn3p08",
#             "tbyn3p08",
#             "tm3n3p02",
#             "tp0n2c08",
#             "tp0n3p08",
#             "tp1n3p08",
#             "xc1n0g08",
#             "xc9n2c08",
#             "xcrn0g04",
#             "xcsn0g01",
#             "xhdn0g08",
#             "xlfn0g04"
#         ]
#     }
# ]

# %% [markdown]
# ## Analyze Msan errors

# %%
file_path = "./_crash_report_msan.txt"
results = extract_error_paths(file_path, 'MSan')

# Find unique errors
unique_results = find_unique_errors(results)
# Out:
#  Uninitialized bytes in strlen at offset 8 inside [0x701000000006, 9)
# ==3806103==WARNING: MemorySanitizer: use-of-uninitialized-value

# %%
# Print the JSON content
print('Total errors: ', len(results))
print('Total unique errors: ', len(unique_results))
print(json.dumps(unique_results, indent=4))
# Out:
# Total errors:  11387
# Total unique errors:  2
# [
#     {
#         "error": "use-of-uninitialized-value",
#         "path": [
#             "read_non_idat_chunks",
#             "read_chunks",
#             "spng_get_plte",
#             "fuzz_spng_read",
#             "main"
#         ],
#         "files": [
#             "ct1n0g04",
#             "cten0g04",
#             "ctfn0g04",
#             "ctgn0g04",
#             "cthn0g04",
#             "ctjn0g04",
#             "ctzn0g04"
#         ]
#     },
#     {
#         "error": "use-of-uninitialized-value",
#         "path": [
#             "memcmp",
#             "trns_row",
#             "spng_decode_scanline",
#             "spng_decode_row",
#             "spng_decode_image",
#             "fuzz_spng_read",
#             "main"
#         ],
#         "files": [
#             "tbbn2c16",
#             "tbgn2c16",
#             "tbrn2c08"
#         ]
#     }
# ]
